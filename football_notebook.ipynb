# %%
import pandas as pd
import numpy as np

# %% [markdown]
# URL: https://www.kaggle.com/datasets/martj42/international-football-results-from-1872-to-2017/code?datasetId=4305&sortBy=voteCount

# %%
print('Leon ist ein Tier')
# Out:
# Leon ist ein Tier
